# %% [markdown]
# # Data Engineering
#
# This notebook should serve as documentation that walks the reader through the data collection and transformations that generate the model's input.
#
# ### Code Standard
#
# When authoring this notebook, please meet the following standards
#
# 1. All major compute operations are organized into seperate code cells
# 1. The output of all major compute operations are displayed in a preceding code cell
# 1. Any code that loads data into production databases is provided and commented out to avoid unintentional data loads.

# %%
# Local environment
import scion_analytics
