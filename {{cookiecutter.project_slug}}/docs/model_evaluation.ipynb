# %% [markdown]
# # Model Report
#
# This notebook should focus on explaining the model with business context. This notebook should produce a report that describes the behavioral profile of the model that can be used to benchmark the model against old and new versions.
#
# - The model's error is reported
# - The model's cost is evaluated
# - Descriptive statistics of model behavior are visualized and displayed

# %%
# YOUR CODE HERE
